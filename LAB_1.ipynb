# %% [markdown]
# <a href="https://colab.research.google.com/github/k-u-s-h-a-g-r-a-k-e-d-i-a/AI-ML-Basics/blob/main/LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/netflix_revenue_updated.csv')
print("Dataset successfully imported")
# Out:
# Dataset successfully imported

# %%
a,b= df.shape
print("Number of rows :",a)
print("Number of columns:",b)
# Out:
# Number of rows : 21
# Number of columns: 15

# %%
print("First 5 rows of dataset")
print(df.head())
# Out:
# First 5 rows of dataset
#          Date  Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# 0  31-03-2019      4520992000              2256851000              1233379000
# 1  30-06-2019      4923116000              2501199000              1319087000
# 2  30-09-2019      5244905000              2621250000              1428040000
# 3  31-12-2019      5467434000              2671908000              1562561000
# 4  31-03-2020      5767691000              2702776000              1723474000
#
#    LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# 0               630472000               319602000      66633000
# 1               677136000               349494000      66501000
# 2               741434000               382304000      67114000
# 3               746392000               418121000      67662000
# 4               793453000               483660000      69969000
#
#    EMEA  Members  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  \
# ...

# %%
print("Dataset size:", df.size)
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Dataset size: 315
# Missing values in each column:
# Date                              0
# Global Revenue                    0
# UCAN Streaming Revenue            0
# EMEA Streaming Revenue            0
# LATM Streaming Revenue            0
# APAC Streaming Revenue            0
# UCAN Members                      0
# EMEA  Members                     0
# LATM Members                      0
# APAC Members                      0
# UCAN ARPU                         0
# EMEA ARPU                         0
# LATM  ARPU                        0
# APAC  ARPU                        0
# Netflix Streaming Memberships     0
# dtype: int64

# %%
print("Sum of numerical columns")
print(df.sum(numeric_only=True))
print("Mean of numerical columns")
print(df.mean(numeric_only=True))
print("Maximum values of numerical columns")
print(df.max(numeric_only=True))
print("Minimum values  of numerical columns")
print(df.min(numeric_only=True))
# Out:
# Sum of numerical columns
# Global Revenue                    1.495596e+11
# UCAN Streaming Revenue            6.732568e+10
# EMEA Streaming Revenue            4.627479e+10
# LATM Streaming Revenue            1.921058e+10
# APAC Streaming Revenue            1.546529e+10
# UCAN Members                      1.540995e+09
# EMEA  Members                     1.435245e+09
# LATM Members                      7.979280e+08
# APAC Members                      6.225880e+08
# UCAN ARPU                         3.076400e+02
# EMEA ARPU                         2.289900e+02
# LATM  ARPU                        1.704000e+02
# APAC  ARPU                        1.837900e+02
# Netflix Streaming Memberships     4.396756e+09
# dtype: float64
# Mean of numerical columns
# Global Revenue                    7.121887e+09
# UCAN Streaming Revenue            3.205985e+09
# EMEA Streaming Revenue            2.203562e+09
# LATM Streaming Revenue            9.147895e+08
# ...

# %%
df.to_csv("Exp1.csv",index=False)
print("Dataset exported successfully")
# Out:
# Dataset exported successfully
